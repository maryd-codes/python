# %%
import sqlite3
import pandas as pd

# %%
testdb = sqlite3.connect('data/test.db') # connect to the dummy database called test.db created yesterday

# %%
pd.read_sql_query("SELECT * FROM orders;", testdb)
# Out:
#     orderno  empno  custno  supplier  price
# 0         1      1      42  Harrison    235
# 1         2      4       1      Ford    234
# 2         3      1      68  Harrison    415
# 3         4      2     112      Ford    350
# 4         5      3      42      Ford    234
# 5         6      2     112      Ford    350
# 6         7      2      42  Harrison    235
# 7         8      4       1      Ford    234
# 8         9      1      68  Harrison    415
# 9        10      2     112      Ford    350
# 10       11      3      42      Ford    234
# 11       12      2     112      Ford    350
# 12       13      2      42  Harrison    235
# 13       14      4       1      Ford    234
# 14       15      1      68  Harrison    415
# 15       16      2     112      Ford    350
# 16       17      3      42      Ford    234
# 17       18      2     112      Ford    350
# 18       19      2      42  Harrison    235

# %% [markdown]
# To use the database, we need to get a **cursor object** and pass the SQL statements to the cursor object to **execute** them. Then, we should **commit** the changes.

# %%
cursor = testdb.cursor()

# %%
add_10_more = [
    (8, 4, 1, "Ford", 234),
    (9, 1, 68, "Harrison", 415),
    (10, 2, 112, "Ford", 350),
    (11, 3, 42, "Ford", 234),
    (12, 2, 112, "Ford", 350),
    (13, 2, 42, "Harrison", 235),
    (14, 4, 1, "Ford", 234),
    (15, 1, 68, "Harrison", 415),
    (16, 2, 112, "Ford", 350),
    (17, 3, 42, "Ford", 234),
    (18, 2, 112, "Ford", 350),
    (19, 2, 42, "Harrison", 235)
]

# %%
cursor.executemany('''INSERT INTO orders
VALUES (?,?,?,?,?)''', add_10_more)
testdb.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-8-ad3d3c175484> in <module>
#       1 cursor.executemany('''INSERT INTO orders
#       2 VALUES (?,?,?,?,?)
# ----> 3 ''', add_10_more)
#       4 testdb.commit()
#
# IntegrityError: UNIQUE constraint failed: orders.orderno

# %%
pd.read_sql_query("SELECT * FROM orders;", testdb)
# Out:
#     orderno  empno  custno  supplier  price
# 0         1      1      42  Harrison    235
# 1         2      4       1      Ford    234
# 2         3      1      68  Harrison    415
# 3         4      2     112      Ford    350
# 4         5      3      42      Ford    234
# 5         6      2     112      Ford    350
# 6         7      2      42  Harrison    235
# 7         8      4       1      Ford    234
# 8         9      1      68  Harrison    415
# 9        10      2     112      Ford    350
# 10       11      3      42      Ford    234
# 11       12      2     112      Ford    350
# 12       13      2      42  Harrison    235
# 13       14      4       1      Ford    234
# 14       15      1      68  Harrison    415
# 15       16      2     112      Ford    350
# 16       17      3      42      Ford    234
# 17       18      2     112      Ford    350
# 18       19      2      42  Harrison    235

# %%
# update a record
cursor.execute('''UPDATE orders
SET supplier == "Ford"
WHERE orderno = 19''')
testdb.commit()

pd.read_sql_query("SELECT * FROM orders;", testdb)
# Out:
#     orderno  empno  custno  supplier  price
# 0         1      1      42  Harrison    235
# 1         2      4       1      Ford    234
# 2         3      1      68  Harrison    415
# 3         4      2     112      Ford    350
# 4         5      3      42      Ford    234
# 5         6      2     112      Ford    350
# 6         7      2      42  Harrison    235
# 7         8      4       1      Ford    234
# 8         9      1      68  Harrison    415
# 9        10      2     112      Ford    350
# 10       11      3      42      Ford    234
# 11       12      2     112      Ford    350
# 12       13      2      42  Harrison    235
# 13       14      4       1      Ford    234
# 14       15      1      68  Harrison    415
# 15       16      2     112      Ford    350
# 16       17      3      42      Ford    234
# 17       18      2     112      Ford    350
# 18       19      2      42      Ford    235

# %%
# delete a record
cursor.execute('''DELETE FROM orders
WHERE orderno = 19''')
testdb.commit()

pd.read_sql_query("SELECT * FROM orders;", testdb)
# Out:
#     orderno  empno  custno  supplier  price
# 0         1      1      42  Harrison    235
# 1         2      4       1      Ford    234
# 2         3      1      68  Harrison    415
# 3         4      2     112      Ford    350
# 4         5      3      42      Ford    234
# 5         6      2     112      Ford    350
# 6         7      2      42  Harrison    235
# 7         8      4       1      Ford    234
# 8         9      1      68  Harrison    415
# 9        10      2     112      Ford    350
# 10       11      3      42      Ford    234
# 11       12      2     112      Ford    350
# 12       13      2      42  Harrison    235
# 13       14      4       1      Ford    234
# 14       15      1      68  Harrison    415
# 15       16      2     112      Ford    350
# 16       17      3      42      Ford    234
# 17       18      2     112      Ford    350

# %%
# simple query
pd.read_sql_query("SELECT DISTINCT supplier FROM orders;", testdb)
# Out:
#    supplier
# 0  Harrison
# 1      Ford

# %%
# complex query
pd.read_sql_query("SELECT empno, price FROM orders WHERE price>400;", testdb)
# Out:
#    empno  price
# 0      1    415
# 1      1    415
# 2      1    415

# %%
# retrieve all data sorted in ascending order on an appropriate field
pd.read_sql_query('''SELECT *
FROM orders
ORDER BY empno ASC
''', testdb)
# Out:
#     orderno  empno  custno  supplier  price
# 0         1      1      42  Harrison    235
# 1         3      1      68  Harrison    415
# 2         9      1      68  Harrison    415
# 3        15      1      68  Harrison    415
# 4         4      2     112      Ford    350
# 5         6      2     112      Ford    350
# 6         7      2      42  Harrison    235
# 7        10      2     112      Ford    350
# 8        12      2     112      Ford    350
# 9        13      2      42  Harrison    235
# 10       16      2     112      Ford    350
# 11       18      2     112      Ford    350
# 12        5      3      42      Ford    234
# 13       11      3      42      Ford    234
# 14       17      3      42      Ford    234
# 15        2      4       1      Ford    234
# 16        8      4       1      Ford    234
# 17       14      4       1      Ford    234
