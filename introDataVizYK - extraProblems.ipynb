# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # What's the richest country in the world on a per-person basis?
# Compare different countries' GDP per capita

# %%
data = pd.read_csv('data/countries.csv')
data.head(2)
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030

# %%
mean_gdpPerCapita = data.groupby(['country']).mean().gdpPerCapita

# %%
top5 = mean_gdpPerCapita.sort_values(ascending=False).head()
top5
# Out:
# country
# Kuwait           65332.910472
# Switzerland      27074.334405
# Norway           26747.306554
# United States    26261.151347
# Canada           22410.746340
# Name: gdpPerCapita, dtype: float64

# %% [markdown]
# ## Is Kuwait really the richest country in the world (on a per-person basis)?
# Investigate by year

# %%
kuwait = data[data.country=='Kuwait']
kuwait.head(2)
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 852  Kuwait      Asia  1952          55.565      160000   108382.3529
# 853  Kuwait      Asia  1957          58.033      212846   113523.1329

# %%
plt.plot(kuwait.year, kuwait.gdpPerCapita)
plt.title('GDP Per Capita in Kuwait (1950 to 2007)')
plt.show()

# %%
# Remember that GDP per capita is GDP per person
plt.subplot(311) # remember order! row, column, ??
plt.title('GDP Per Capita')
plt.plot(kuwait.year, kuwait.gdpPerCapita)

plt.subplot(312)
plt.title('GDP in Billions')
plt.plot(kuwait.year, kuwait.population*kuwait.gdpPerCapita/10**9)

plt.subplot(313)
plt.title('Population in Millions')
plt.plot(kuwait.year, kuwait.population/10**6)

plt.tight_layout()
plt.show()

# %%
# Try comparing relative growth in one chart
plt.plot(kuwait.year, kuwait.population/kuwait.population.iloc[0]*100)

kuwait_gdp = kuwait.population*kuwait.gdpPerCapita
plt.plot(kuwait.year, kuwait_gdp/kuwait_gdp.iloc[0]*100)
plt.plot(kuwait.year, kuwait.gdpPerCapita/kuwait.gdpPerCapita.iloc[0]*100)
plt.title('GDP and Population Growth in Kuwait (first year =100)')
plt.legend(['Population', 'GDP', 'GDP Per Capita'])

plt.show()

# %%
# Remember
top5
# Out:
# country
# Kuwait           65332.910472
# Switzerland      27074.334405
# Norway           26747.306554
# United States    26261.151347
# Canada           22410.746340
# Name: gdpPerCapita, dtype: float64

# %%
# Compare how the GDP per capita in the US has changed over time

# %%
us = data[data.country=='United States']

# %%
plt.plot(us.year, us.gdpPerCapita)
plt.plot(kuwait.year, kuwait.gdpPerCapita)
plt.legend(['United States','Kuwait'])

plt.show()

# %% [markdown]
# ## So is Kuwait really the richest country in the world (on a per-person basis)?
# Not so straight forward-- certainly they may have been between 1950 and 1970 but perhaps not so today.

# %% [markdown]
# # Other questions for countries.csv
#
# * What's the fastest growing country in the world in terms of GDP?
# * Which country resembles the US the most?
# * How is population related to GDP per capita?
